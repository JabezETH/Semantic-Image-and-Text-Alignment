# %%
import pandas as pd
import sys
sys.path.insert(1, '/home/jabez_kassa/week_12/Semantic-Image-and-Text-Alignment/scripts')
data = pd.read_csv('/home/jabez_kassa/week_12/Semantic-Image-and-Text-Alignment/data/performance_data.csv')
import plot

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 905 entries, 0 to 904
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   game_id       905 non-null    object
#  1   preview_link  905 non-null    object
#  2   ER            905 non-null    float64
#  3   CTR           905 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 28.4+ KB

# %%
plot.box_plot(data)

# %%
plot.scatter_plot(data, column1='ER', column2='CTR')

# %%
plot.density_plot(data, column1='ER', column2='CTR')
# Out:
# /home/jabez_kassa/week_12/Semantic-Image-and-Text-Alignment/scripts/plot.py:18: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=df[column1], y=df[column2], cmap="Reds", shade=True, thresh=0.05)

# %%
data['preview_link']
# Out:
# 0      https://s3.us-east-1.amazonaws.com/a.futureadl...
# 1      https://s3.us-east-1.amazonaws.com/a.futureadl...
# 2      https://s3.us-east-1.amazonaws.com/a.futureadl...
# 3      https://s3.ap-southeast-1.amazonaws.com/a.futu...
# 4      https://s3.us-west-1.amazonaws.com/a.futureadl...
#                              ...
# 900    https://s3.eu-west-1.amazonaws.com/a.futureadl...
# 901    https://s3.us-east-1.amazonaws.com/a.futureadl...
# 902    https://s3.ap-southeast-1.amazonaws.com/a.futu...
# 903    https://s3.us-east-1.amazonaws.com/a.futureadl...
# 904    https://s3.ap-southeast-1.amazonaws.com/a.futu...
# Name: preview_link, Length: 905, dtype: object

# %%
data['game_id']
# Out:
# 0                       bfbf7a2b7ac635e67877b1ab87fd6629
# 1                       945010afbf9a55bbdffcb0895f946155
# 2                       e68e20f592457b875ce29757ab855dfe
# 3                      adunit-nestle-purina-friskies-mob
# 4      adunit-lionsgate-uwomt-user-slider-sensory-vid...
#                              ...
# 900                     2443bd3b890824acecbe32659b9a1246
# 901                     7ed73c1cc404f9956d26c5f58de72b2f
# 902                     90455f5ace15860874965eabd081b6f2
# 903                      adunit-chevy-hotspot-cpe-av-mpu
# 904    adunit-facebook-conversational-commerce-3-0-vn...
# Name: game_id, Length: 905, dtype: object

# %%
data.sort_values('ER', ascending=False)
# Out:
#                                                game_id  \
# 357                   0792c911c288bd241c1e2a2b64bce488
# 856                   015efcdd8de3698ffc4dad6dabd6664a
# 40                    07f93a53c25007301d276ec20e7be491
# 208       adunit-mouser-user-choice-flight4-uk-cpe-mob
# 33                    6a3dbf08b82e45b3f3e79844f3a9aa18
# ..                                                 ...
# 42   adunit-simple-feast-build-for-industry-survey-...
# 242                   ae30ff3cae1f369954f5e91499b9e515
# 291               adunit-ihop-ihoppy-hour-no-offer-mpu
# 116                   4e3305a488faf871189cce9831a6c863
# 848                     adunit-engagementplus-ihop-mpu
#
#                                           preview_link        ER       CTR
# 357  https://s3.eu-west-1.amazonaws.com/a.futureadl...  0.524498  0.025249
# 856  https://s3.eu-west-1.amazonaws.com/a.futureadl...  0.446696  0.034950
# 40   https://s3.ap-southeast-1.amazonaws.com/a.futu...  0.440421  0.020432
# ...

# %%
data.sort_values('CTR', ascending=False)
# Out:
#                                                game_id  \
# 161                   6befe54086758294b47addf0c12052a7
# 371                   f033db746b20e747ee528caa07f0b2de
# 507                   eb641577b39bf60665e3130ac0d4e301
# 560                   79a672060e901ce418230c3959619cca
# 698                   77af46ea55c251a18213104bd760d1d2
# ..                                                 ...
# 525  adunit-western-union-ralphs-sensory-engagement...
# 509  adunit-western-union-ralphs-sensory-eng-auto-e...
# 480  adunit-facebook-conversational-commerce-3-0-th...
# 457           adunit-western-union-ralphs-scrub-v2-mpu
# 904  adunit-facebook-conversational-commerce-3-0-vn...
#
#                                           preview_link        ER       CTR
# 161  https://s3.ap-east-1.amazonaws.com/a.futureadl...  0.327068  0.297410
# 371  https://s3.ap-east-1.amazonaws.com/a.futureadl...  0.306202  0.293282
# 507  https://s3.ap-east-1.amazonaws.com/a.futureadl...  0.360153  0.280241
# ...
